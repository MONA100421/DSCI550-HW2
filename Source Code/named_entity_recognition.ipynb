# %% [markdown]
# #  Named Entity Recognition (NER) with SpaCy

# %% [markdown]
# ### Install and set up SpaCy

# %%
# !pip install tika spacy pandas numpy requests
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: tika in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (2.6.0)
# Requirement already satisfied: spacy in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (3.7.5)
# Requirement already satisfied: pandas in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (1.4.0)
# Requirement already satisfied: numpy in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (1.24.4)
# Requirement already satisfied: requests in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (2.24.0)
# Requirement already satisfied: setuptools in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from tika) (75.3.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy) (8.2.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy) (4.50.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.10.6)
# Requirement already satisfied: jinja2 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.11.2)
# Requirement already satisfied: packaging>=20.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy) (3.4.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2020.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from requests) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from requests) (2025.1.31)
# Requirement already satisfied: language-data>=1.2 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: six>=1.5 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.15.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (6.3.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy) (1.1.1)
# Requirement already satisfied: marisa-trie>=1.1.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 7.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.50.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.24.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.10.6)
# Requirement already satisfied: jinja2 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.11.2)
# Requirement already satisfied: setuptools in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (75.3.2)
# Requirement already satisfied: packaging>=20.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.4)
# Requirement already satisfied: language-data>=1.2 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.3.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.1)
# Requirement already satisfied: marisa-trie>=1.1.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/niromikha/opt/anaconda3/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import pandas as pd
import spacy
import requests
from tika import parser

# %%
# Load the dataset
df = pd.read_csv("../data/haunted_religious_historic_crime_merged.tsv", sep='\t')

# Display the first few rows
df.head()
# Out:
#    Unnamed: 0     city        country  \
# 0           0      Ada  United States
# 1           1  Addison  United States
# 2           2   Adrian  United States
# 3           3   Adrian  United States
# 4           4   Albion  United States
#
#                                          description  \
# 0  Ada witch - Sometimes you can see a misty blue...
# 1  A little girl was killed suddenly while waitin...
# 2  If you take Gorman Rd. west towards Sand Creek...
# 3  In the 1970's, one room, room 211, in the old ...
# 4  Kappa Delta Sorority - The Kappa Delta Sororit...
#
#                    location     state state_abbrev  longitude   latitude  \
# 0              Ada Cemetery  Michigan           MI -85.504893  42.962106
# 1           North Adams Rd.  Michigan           MI -84.381843  41.971425
# 2             Ghost Trestle  Michigan           MI -84.035656  41.904538
# 3  Siena Heights University  Michigan           MI -84.017565  41.905712
# 4            Albion College  Michigan           MI -84.745177  42.244006
#
#    city_longitude  ...  Adherents  Adherents as % of Population  \
# 0      -85.495480  ...   282420.0                      0.429227
# 1      -84.347168  ...    11128.0                      0.243256
# 2      -84.037166  ...    33427.0                      0.336210
# 3      -84.037166  ...    33427.0                      0.336210
# 4      -84.753030  ...    43340.0                      0.322686
#
#    Haunted Houses Count per County crime_rate_per_100000  MURDER ROBBERY  \
# 0                             46.0            395.689239    22.0   639.0
# 1                              3.0            190.885230     0.0     2.0
# 2                              3.0            205.670041     4.0    22.0
# 3                              3.0            205.670041     4.0    22.0
# 4                             19.0            602.168696    11.0   112.0
#
#   BURGLRY                           nearest_historical_place  \
# 0  3878.0                                 Ada Covered Bridge
# 1   180.0                                                NaN
# 2   335.0                          Lenawee County Courthouse
# 3   335.0  Dennis and State Streets Historic District (Bo...
# 4  1405.0       Superior Street Commercial Historic District
#
#    num_historical_places_5mi  year_of_nearest_historical_place
# 0                          2                            1970.0
# 1                          0                               NaN
# 2                         12                            1991.0
# 3                         12                            1979.0
# 4                          2                            1997.0
#
# [5 rows x 52 columns]

# %% [markdown]
# ### Load the pre-trained SpaCy model for English NLP tasks

# %%
nlp = spacy.load("en_core_web_sm") #load the pre-trained SpaCy model for English NLP tasks

# %%
def extract_named_entities(text):
    if pd.isna(text):  # Handle missing values
        return []
    doc = nlp(text)
    return [(ent.text, ent.label_) for ent in doc.ents]

df['Named_Entities'] = df['description'].apply(lambda x: extract_named_entities(x)) #apply the extracted named entities and save to a new column

# %%
df['Named_Entities']
# Out:
# 0        [(Ada witch -, PERSON), (3-mile, QUANTITY), (t...
# 1                  [(month later, DATE), (this day, DATE)]
# 2        [(Gorman Rd, PERSON), (Sand Creek, FAC), (A mi...
# 3        [(1970, DATE), (one, CARDINAL), (211, CARDINAL...
# 4        [(Kappa Delta Sorority - The Kappa Delta Soror...
#                                ...
# 10969    [(12 midnight, TIME), (two, CARDINAL), (Sherid...
# 10970                                  [(years ago, DATE)]
# 10971    [(18 years old, DATE), (70, DATE), (one, CARDI...
# 10972                                                   []
# 10973     [(the Air Force Academy, ORG), (Survival, NORP)]
# Name: Named_Entities, Length: 10974, dtype: object

# %%
print(df[["description", "Named_Entities"]].head())
# Out:
#                                          description  \
# 0  Ada witch - Sometimes you can see a misty blue...
# 1  A little girl was killed suddenly while waitin...
# 2  If you take Gorman Rd. west towards Sand Creek...
# 3  In the 1970's, one room, room 211, in the old ...
# 4  Kappa Delta Sorority - The Kappa Delta Sororit...
#
#                                       Named_Entities
# 0  [(Ada witch -, PERSON), (3-mile, QUANTITY), (t...
# 1            [(month later, DATE), (this day, DATE)]
# 2  [(Gorman Rd, PERSON), (Sand Creek, FAC), (A mi...
# 3  [(1970, DATE), (one, CARDINAL), (211, CARDINAL...
# 4  [(Kappa Delta Sorority - The Kappa Delta Soror...

# %% [markdown]
# ### Save it to a new tsv file

# %%
df.to_csv("../Data/merged_data_v2_with_entities.tsv", sep="\t", index=False)
