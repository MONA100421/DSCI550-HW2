# %%
# !git clone https://github.com/USCDataScience/tika-dockers.git
# Out:
# fatal: destination path 'tika-dockers' already exists and is not an empty directory.

# %%
# !docker pull uscdatascience/im2txt-rest-tika
# Out:
# Using default tag: latest
# latest: Pulling from uscdatascience/im2txt-rest-tika
# Digest: sha256:2d51eabc476369335ff83e393a166b1b08e41d4b3cacd34860fc3dd73176eb9c
# Status: Image is up to date for uscdatascience/im2txt-rest-tika:latest
# docker.io/uscdatascience/im2txt-rest-tika:latest

# %%
# !docker build -f tika-dockers/Im2txtRestDockerfile -t im2txt-rest-tika .
# Out:
# [+] Building 0.0s (0/0)  docker:default
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.1s (1/1)                                          docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.1s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.1s
# [+] Building 0.3s (1/2)                                          docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.1s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.1s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.2s
# [+] Building 0.3s (1/3)                                          docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.1s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.1s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.2s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
# [+] Building 0.5s (2/3)                                          docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.1s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.1s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.3s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
# [+] Building 0.6s (2/3)                                          docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.1s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.1s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.5s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
# [+] Building 0.7s (3/3)                                          docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.1s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.1s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.6s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
# [+] Building 0.8s (13/13) FINISHED                               docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.1s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.1s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.6s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256:dd104c  0.0s
#  => CACHED [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/   0.0s
#  => CACHED [3/9] RUN echo "We're downloading the checkpoint file for imag  0.0s
#  => CACHED [4/9] RUN curl -O https://raw.githubusercontent.com/apache/tik  0.0s
#  => CACHED [5/9] WORKDIR /usr/share/apache-tika/src/dl/image/caption/      0.0s
#  => CACHED [6/9] RUN curl -O https://raw.githubusercontent.com/apache/tik  0.0s
#  => CACHED [7/9] RUN apt-get -y remove         apt-utils         curl      0.0s
#  => CACHED [8/9] RUN ln -s /usr/share/apache-tika/src/dl/image/caption/im  0.0s
#  => exporting to image                                                     0.0s
#  => => exporting layers                                                    0.0s
#  => => writing image sha256:adc73f89ce12de2f1981b601a859e89beafdb934137f4  0.0s
#  => => naming to docker.io/library/im2txt-rest-tika                        0.0s
#
#  2 warnings found (use docker --debug to expand):
#  - MaintainerDeprecated: Maintainer instruction is deprecated in favor of using label (line 19)
#  - JSONArgsRecommended: JSON arguments recommended for CMD to prevent unintended behavior related to OS signals (line 60)

# %%
# !docker run -it -p 8764:8764 im2txt-rest-tika
# Out:
# INFO:tensorflow:Building model.
# INFO:tensorflow:Initializing vocabulary from file: /usr/share/apache-tika/models/dl/image/caption/1M_iters_ckpt/word_counts.txt
# INFO:tensorflow:Created vocabulary with 11520 words
# 2025-04-03 21:07:04.421988: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# INFO:tensorflow:Loading model from checkpoint: /usr/share/apache-tika/models/dl/image/caption/1M_iters_ckpt/model.ckpt-1000000
# INFO:tensorflow:Restoring parameters from /usr/share/apache-tika/models/dl/image/caption/1M_iters_ckpt/model.ckpt-1000000
# INFO:tensorflow:Successfully loaded checkpoint: model.ckpt-1000000
# Serving on port 8764
#  * Serving Flask app "im2txtapi" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0