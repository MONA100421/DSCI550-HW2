# %%
# !git clone https://github.com/USCDataScience/tika-dockers.git
# Out:
# fatal: destination path 'tika-dockers' already exists and is not an empty directory.

# %%
# !docker pull uscdatascience/im2txt-rest-tika
# Out:
# Using default tag: latest
# latest: Pulling from uscdatascience/im2txt-rest-tika
# Digest: sha256:2d51eabc476369335ff83e393a166b1b08e41d4b3cacd34860fc3dd73176eb9c
# Status: Image is up to date for uscdatascience/im2txt-rest-tika:latest
# docker.io/uscdatascience/im2txt-rest-tika:latest

# %%
# !docker build -f tika-dockers/Im2txtRestDockerfile -t im2txt-rest-tika .
# Out:
# [+] Building 0.0s (0/0)  docker:default
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (2/3)                                          docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.2s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
# [+] Building 0.4s (2/3)                                          docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.3s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
# [+] Building 0.5s (2/3)                                          docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.5s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
# [+] Building 0.7s (2/3)                                          docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.6s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
# [+] Building 0.7s (3/3)                                          docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
# [+] Building 0.9s (5/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.1s
# [+] Building 1.1s (5/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.3s
# [+] Building 1.2s (5/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.4s
# [+] Building 1.4s (5/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
# [+] Building 1.4s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
# [+] Building 1.6s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  0.2s
# [+] Building 1.7s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  0.3s
# [+] Building 1.9s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  0.5s
# [+] Building 2.0s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  0.6s
# [+] Building 2.2s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  0.8s
# [+] Building 2.3s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  0.9s
# [+] Building 2.5s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  1.1s
# [+] Building 2.5s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  1.1s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
# [+] Building 2.6s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  1.2s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
# [+] Building 2.8s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  1.4s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
# [+] Building 2.9s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  1.5s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
# [+] Building 3.1s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  1.7s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
# [+] Building 3.2s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  1.8s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
# [+] Building 3.2s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  1.8s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 3.4s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  2.0s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 3.5s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  2.1s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 3.7s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  2.3s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 3.8s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  2.4s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 4.0s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  2.6s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 4.1s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  2.7s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 4.3s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  2.9s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 4.4s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  3.0s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 4.6s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  3.2s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 4.7s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  3.3s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 4.9s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  3.5s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 5.0s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  3.6s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 5.2s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  3.8s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 5.3s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  3.9s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 5.5s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  4.1s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 5.6s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  4.2s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 5.8s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  4.4s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 5.9s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  4.5s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 6.1s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  4.7s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 6.2s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  4.8s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 6.4s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  5.0s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 6.5s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  5.1s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 6.7s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  5.3s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 6.8s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  5.4s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
#  => => # Cloning into 'img2text'...
# [+] Building 7.0s (6/12)                                         docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capti  5.6s
#  => => # We're downloading the checkpoint file for image captioning, the shell
#  => => # might look unresponsive. Please be patient.
# ...
# [+] Building 72.6s (12/13)                                       docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capt  57.6s
#  => [4/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.1s
#  => [5/9] WORKDIR /usr/share/apache-tika/src/dl/image/caption/             0.1s
#  => [6/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.4s
#  => [7/9] RUN apt-get -y remove         apt-utils         curl         gi  1.4s
#  => [8/9] RUN ln -s /usr/share/apache-tika/src/dl/image/caption/im2txtapi  0.2s
#  => exporting to image                                                     9.5s
#  => => exporting layers                                                    9.5s
# [+] Building 72.8s (12/13)                                       docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capt  57.6s
#  => [4/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.1s
#  => [5/9] WORKDIR /usr/share/apache-tika/src/dl/image/caption/             0.1s
#  => [6/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.4s
#  => [7/9] RUN apt-get -y remove         apt-utils         curl         gi  1.4s
#  => [8/9] RUN ln -s /usr/share/apache-tika/src/dl/image/caption/im2txtapi  0.2s
#  => exporting to image                                                     9.6s
#  => => exporting layers                                                    9.6s
# [+] Building 72.9s (12/13)                                       docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capt  57.6s
#  => [4/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.1s
#  => [5/9] WORKDIR /usr/share/apache-tika/src/dl/image/caption/             0.1s
#  => [6/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.4s
#  => [7/9] RUN apt-get -y remove         apt-utils         curl         gi  1.4s
#  => [8/9] RUN ln -s /usr/share/apache-tika/src/dl/image/caption/im2txtapi  0.2s
#  => exporting to image                                                     9.8s
#  => => exporting layers                                                    9.8s
# [+] Building 73.1s (12/13)                                       docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capt  57.6s
#  => [4/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.1s
#  => [5/9] WORKDIR /usr/share/apache-tika/src/dl/image/caption/             0.1s
#  => [6/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.4s
#  => [7/9] RUN apt-get -y remove         apt-utils         curl         gi  1.4s
#  => [8/9] RUN ln -s /usr/share/apache-tika/src/dl/image/caption/im2txtapi  0.2s
#  => exporting to image                                                     9.9s
#  => => exporting layers                                                    9.9s
# [+] Building 73.2s (12/13)                                       docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capt  57.6s
#  => [4/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.1s
#  => [5/9] WORKDIR /usr/share/apache-tika/src/dl/image/caption/             0.1s
#  => [6/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.4s
#  => [7/9] RUN apt-get -y remove         apt-utils         curl         gi  1.4s
#  => [8/9] RUN ln -s /usr/share/apache-tika/src/dl/image/caption/im2txtapi  0.2s
#  => exporting to image                                                    10.1s
#  => => exporting layers                                                   10.1s
# [+] Building 73.4s (12/13)                                       docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capt  57.6s
#  => [4/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.1s
#  => [5/9] WORKDIR /usr/share/apache-tika/src/dl/image/caption/             0.1s
#  => [6/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.4s
#  => [7/9] RUN apt-get -y remove         apt-utils         curl         gi  1.4s
#  => [8/9] RUN ln -s /usr/share/apache-tika/src/dl/image/caption/im2txtapi  0.2s
#  => exporting to image                                                    10.2s
#  => => exporting layers                                                   10.2s
# [+] Building 73.5s (12/13)                                       docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capt  57.6s
#  => [4/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.1s
#  => [5/9] WORKDIR /usr/share/apache-tika/src/dl/image/caption/             0.1s
#  => [6/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.4s
#  => [7/9] RUN apt-get -y remove         apt-utils         curl         gi  1.4s
#  => [8/9] RUN ln -s /usr/share/apache-tika/src/dl/image/caption/im2txtapi  0.2s
#  => exporting to image                                                    10.4s
#  => => exporting layers                                                   10.4s
# [+] Building 73.7s (12/13)                                       docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capt  57.6s
#  => [4/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.1s
#  => [5/9] WORKDIR /usr/share/apache-tika/src/dl/image/caption/             0.1s
#  => [6/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.4s
#  => [7/9] RUN apt-get -y remove         apt-utils         curl         gi  1.4s
#  => [8/9] RUN ln -s /usr/share/apache-tika/src/dl/image/caption/im2txtapi  0.2s
#  => exporting to image                                                    10.5s
#  => => exporting layers                                                   10.5s
# [+] Building 73.8s (12/13)                                       docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capt  57.6s
#  => [4/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.1s
#  => [5/9] WORKDIR /usr/share/apache-tika/src/dl/image/caption/             0.1s
#  => [6/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.4s
#  => [7/9] RUN apt-get -y remove         apt-utils         curl         gi  1.4s
#  => [8/9] RUN ln -s /usr/share/apache-tika/src/dl/image/caption/im2txtapi  0.2s
#  => exporting to image                                                    10.7s
#  => => exporting layers                                                   10.7s
# [+] Building 73.9s (12/13)                                       docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capt  57.6s
#  => [4/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.1s
#  => [5/9] WORKDIR /usr/share/apache-tika/src/dl/image/caption/             0.1s
#  => [6/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.4s
#  => [7/9] RUN apt-get -y remove         apt-utils         curl         gi  1.4s
#  => [8/9] RUN ln -s /usr/share/apache-tika/src/dl/image/caption/im2txtapi  0.2s
#  => exporting to image                                                    10.7s
#  => => exporting layers                                                   10.7s
# [+] Building 74.0s (13/13) FINISHED                              docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.0s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.0s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.7s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256  0.0s
#  => [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/          0.6s
#  => [3/9] RUN echo "We're downloading the checkpoint file for image capt  57.6s
#  => [4/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.1s
#  => [5/9] WORKDIR /usr/share/apache-tika/src/dl/image/caption/             0.1s
#  => [6/9] RUN curl -O https://raw.githubusercontent.com/apache/tika/maste  1.4s
#  => [7/9] RUN apt-get -y remove         apt-utils         curl         gi  1.4s
#  => [8/9] RUN ln -s /usr/share/apache-tika/src/dl/image/caption/im2txtapi  0.2s
#  => exporting to image                                                    10.8s
#  => => exporting layers                                                   10.7s
#  => => writing image sha256:adc73f89ce12de2f1981b601a859e89beafdb934137f4  0.0s
#  => => naming to docker.io/library/im2txt-rest-tika                        0.0s

# %%
# !docker run -it -p 8764:8764 im2txt-rest-tika
# Out:
# INFO:tensorflow:Building model.
# INFO:tensorflow:Initializing vocabulary from file: /usr/share/apache-tika/models/dl/image/caption/1M_iters_ckpt/word_counts.txt
# INFO:tensorflow:Created vocabulary with 11520 words
# 2025-04-03 08:17:45.460032: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# INFO:tensorflow:Loading model from checkpoint: /usr/share/apache-tika/models/dl/image/caption/1M_iters_ckpt/model.ckpt-1000000
# INFO:tensorflow:Restoring parameters from /usr/share/apache-tika/models/dl/image/caption/1M_iters_ckpt/model.ckpt-1000000
# INFO:tensorflow:Successfully loaded checkpoint: model.ckpt-1000000
# Serving on port 8764
#  * Serving Flask app "im2txtapi" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:8764/ (Press CTRL+C to quit)
# 172.17.0.1 - - [03/Apr/2025 08:17:54] "GET / HTTP/1.1" 200 -
# /usr/local/lib/python2.7/dist-packages/werkzeug/filesystem.py:63: BrokenFilesystemWarning: Detected a misconfigured UNIX filesystem: Will use UTF-8 as filesystem encoding instead of 'ANSI_X3.4-1968'
#   BrokenFilesystemWarning)
# 172.17.0.1 - - [03/Apr/2025 08:20:08] "GET /inception/v3/caption/image?url=https://ca-times.brightspotcdn.com/dims4/default/df0a5c1/2147483647/strip/true/crop/6240x4160+0+0/resize/1200x800\!/quality/75/?url=https%3A%2F%2Fcalifornia-times-brightspot.s3.amazonaws.com%2F5c%2Fa2%2Fbb33b2164176ba4ff6bc28a6c971%2F1406433-me-laweather-feb-rain-rc23.jpg HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 08:21:47] "GET /inception/v3/caption/image?url=https://ca-times.brightspotcdn.com/dims4/default/df0a5c1/2147483647/strip/true/crop/6240x4160+0+0/resize/1200x800%21/quality/75/?url=https%3A%2F%2Fcalifornia-times-brightspot.s3.amazonaws.com%2F5c%2Fa2%2Fbb33b2164176ba4ff6bc28a6c971%2F1406433-me-laweather-feb-rain-rc23.jpg HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 08:26:56] "GET /inception/v3/caption/image?url=https://ca-times.brightspotcdn.com/dims4/default/df0a5c1/2147483647/strip/true/crop/6240x4160+0+0/resize/1200x800%21/quality/75/?url=https%3A%2F%2Fcalifornia-times-brightspot.s3.amazonaws.com%2F5c%2Fa2%2Fbb33b2164176ba4ff6bc28a6c971%2F1406433-me-laweather-feb-rain-rc23.jpg HTTP/1.1" 200 -
# [2025-04-03 08:32:37,830] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406da9110>
# 172.17.0.1 - - [03/Apr/2025 08:32:37] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:37,970] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406357dd0>
# 172.17.0.1 - - [03/Apr/2025 08:32:37] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:37,979] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406da9110>
# 172.17.0.1 - - [03/Apr/2025 08:32:37] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:37,999] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406357dd0>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,012] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406da9110>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,019] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406357dd0>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,031] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406da9110>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,037] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406357dd0>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,043] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406da9110>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,063] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406357dd0>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,070] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406da9110>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,107] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406357dd0>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,128] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406da9110>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,148] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406357dd0>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,181] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406da9110>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,213] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406357dd0>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,234] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406da9110>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,252] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406357dd0>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,266] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406da9110>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,281] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406357dd0>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,299] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406da9110>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,306] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406357dd0>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,321] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406da9110>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,335] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406357dd0>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,352] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406da9110>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,389] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406357dd0>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,410] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406da9110>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,426] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406357dd0>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,436] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406da9110>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,447] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406357dd0>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,465] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406da9110>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,496] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406357dd0>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,533] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406da9110>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,545] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406357dd0>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,552] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406da9110>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,575] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406357dd0>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,587] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
#     image = Image.open(BytesIO(image_data))
#   File "/usr/local/lib/python2.7/dist-packages/PIL/Image.py", line 2622, in open
#     % (filename if filename else fp))
# IOError: cannot identify image file <_io.BytesIO object at 0x7c7406da9110>
# 172.17.0.1 - - [03/Apr/2025 08:32:38] "POST /inception/v3/caption/image HTTP/1.1" 500 -
# [2025-04-03 08:32:38,596] ERROR in app: Exception on /inception/v3/caption/image [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python2.7/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/usr/bin/im2txtapi", line 215, in caption_image
# ...
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_13.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_14.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_15.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_16.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_17.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_18.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_19.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_20.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_21.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_22.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_23.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_24.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_25.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_26.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_27.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_28.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_29.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_30.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_31.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_32.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_33.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_34.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_35.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_36.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_37.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_38.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_39.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_40.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_41.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_42.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_43.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_44.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_45.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_46.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:40] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_47.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_48.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_49.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_50.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_51.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_52.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_53.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_54.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_55.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_56.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_57.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_58.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_59.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_60.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_61.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_62.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_63.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_64.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_65.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_66.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_67.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_68.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_69.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_70.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_71.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_72.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_73.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_74.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_75.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_76.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_77.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_78.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_79.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_80.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_81.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_82.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_83.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_84.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_85.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_86.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_87.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_88.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_89.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_90.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_91.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_92.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_93.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_94.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_95.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_96.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_97.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_98.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
# 172.17.0.1 - - [03/Apr/2025 08:52:41] "GET /inception/v3/captions?url=http%3A%2F%2Flocalhost%3A8000%2Fimages%2Fhaunted_image_99.png&beam_size=3&max_caption_length=15 HTTP/1.1" 404 -
