# %%
# !git clone https://github.com/USCDataScience/tika-dockers.git
# Out:
# fatal: destination path 'tika-dockers' already exists and is not an empty directory.

# %%
# !docker pull uscdatascience/im2txt-rest-tika
# Out:
# Using default tag: latest
# latest: Pulling from uscdatascience/im2txt-rest-tika
# Digest: sha256:2d51eabc476369335ff83e393a166b1b08e41d4b3cacd34860fc3dd73176eb9c
# Status: Image is up to date for uscdatascience/im2txt-rest-tika:latest
# docker.io/uscdatascience/im2txt-rest-tika:latest

# %%
# !docker build -f tika-dockers/Im2txtRestDockerfile -t im2txt-rest-tika .
# Out:
# [+] Building 0.0s (0/0)  docker:default
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.1s (1/1)                                          docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.1s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.1s
# [+] Building 0.3s (1/2)                                          docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.1s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.1s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.2s
# [+] Building 0.3s (1/3)                                          docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.1s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.1s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.2s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
# [+] Building 0.5s (2/3)                                          docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.1s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.1s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.3s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
# [+] Building 0.6s (2/3)                                          docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.1s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.1s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.5s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
# [+] Building 0.7s (3/3)                                          docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.1s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.1s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.6s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
# [+] Building 0.8s (13/13) FINISHED                               docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.1s
#  => => transferring dockerfile: 2.73kB                                     0.0s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.1s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.6s
#  => [auth] uscdatascience/tf-tika-base:pull token for registry-1.docker.i  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/9] FROM docker.io/uscdatascience/tf-tika-base:latest@sha256:dd104c  0.0s
#  => CACHED [2/9] WORKDIR /usr/share/apache-tika/models/dl/image/caption/   0.0s
#  => CACHED [3/9] RUN echo "We're downloading the checkpoint file for imag  0.0s
#  => CACHED [4/9] RUN curl -O https://raw.githubusercontent.com/apache/tik  0.0s
#  => CACHED [5/9] WORKDIR /usr/share/apache-tika/src/dl/image/caption/      0.0s
#  => CACHED [6/9] RUN curl -O https://raw.githubusercontent.com/apache/tik  0.0s
#  => CACHED [7/9] RUN apt-get -y remove         apt-utils         curl      0.0s
#  => CACHED [8/9] RUN ln -s /usr/share/apache-tika/src/dl/image/caption/im  0.0s
#  => exporting to image                                                     0.0s
#  => => exporting layers                                                    0.0s
#  => => writing image sha256:adc73f89ce12de2f1981b601a859e89beafdb934137f4  0.0s
#  => => naming to docker.io/library/im2txt-rest-tika                        0.0s
#
#  2 warnings found (use docker --debug to expand):
#  - MaintainerDeprecated: Maintainer instruction is deprecated in favor of using label (line 19)
#  - JSONArgsRecommended: JSON arguments recommended for CMD to prevent unintended behavior related to OS signals (line 60)

# %%
# !docker run -it -p 8764:8764 im2txt-rest-tika
# Out:
# INFO:tensorflow:Building model.
# INFO:tensorflow:Initializing vocabulary from file: /usr/share/apache-tika/models/dl/image/caption/1M_iters_ckpt/word_counts.txt
# INFO:tensorflow:Created vocabulary with 11520 words
# 2025-04-03 21:07:04.421988: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# INFO:tensorflow:Loading model from checkpoint: /usr/share/apache-tika/models/dl/image/caption/1M_iters_ckpt/model.ckpt-1000000
# INFO:tensorflow:Restoring parameters from /usr/share/apache-tika/models/dl/image/caption/1M_iters_ckpt/model.ckpt-1000000
# INFO:tensorflow:Successfully loaded checkpoint: model.ckpt-1000000
# Serving on port 8764
#  * Serving Flask app "im2txtapi" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:8764/ (Press CTRL+C to quit)
# /usr/local/lib/python2.7/dist-packages/werkzeug/filesystem.py:63: BrokenFilesystemWarning: Detected a misconfigured UNIX filesystem: Will use UTF-8 as filesystem encoding instead of 'ANSI_X3.4-1968'
#   BrokenFilesystemWarning)
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3500.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3501.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3502.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3503.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3504.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3505.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3506.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3507.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3508.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3509.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3510.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3511.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3512.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3513.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3514.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3515.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3516.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3517.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3518.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3519.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3520.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3521.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3522.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3523.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3524.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3525.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3526.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3527.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3528.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3529.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3530.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3531.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3532.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3533.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3534.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3535.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3536.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3537.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3538.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3539.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3540.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3541.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3542.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3543.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3544.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3545.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3546.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3547.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3548.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3549.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3550.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3551.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3552.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3553.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3554.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3555.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3556.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3557.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3558.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3559.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# 172.17.0.1 - - [03/Apr/2025 21:07:34] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_3560.png&beam_size=5&max_caption_length=20 HTTP/1.1" 500 -
# Error on request:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/serving.py", line 260, in execute
#     for data in application_iter:
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wsgi.py", line 870, in __next__
#     return self._next()
#   File "/usr/local/lib/python2.7/dist-packages/werkzeug/wrappers.py", line 82, in _iter_encoded
#     for item in iterable:
# TypeError: 'Response' object is not iterable
# ...
# 172.17.0.1 - - [03/Apr/2025 21:49:44] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4916.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:49:45] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4917.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:49:46] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4918.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:49:47] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4919.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:49:49] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4920.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:49:50] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4921.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:49:51] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4922.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:49:52] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4923.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:49:54] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4924.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:49:55] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4925.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:49:56] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4926.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:49:57] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4927.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:49:59] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4928.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:00] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4929.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:01] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4930.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:02] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4931.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:04] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4932.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:05] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4933.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:06] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4934.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:07] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4935.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:09] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4936.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:10] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4937.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:11] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4938.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:12] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4939.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:14] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4940.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:15] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4941.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:16] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4942.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:17] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4943.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:19] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4944.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:20] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4945.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:21] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4946.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:22] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4947.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:23] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4948.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:25] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4949.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:26] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4950.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:27] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4951.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:28] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4952.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:30] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4953.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:31] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4954.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:32] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4955.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:33] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4956.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:35] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4957.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:36] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4958.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:37] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4959.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:39] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4960.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:40] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4961.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:42] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4962.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:43] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4963.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:44] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4964.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:45] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4965.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:47] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4966.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:48] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4967.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:49] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4968.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:50] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4969.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:52] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4970.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:53] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4971.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:54] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4972.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:55] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4973.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:57] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4974.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:58] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4975.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:50:59] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4976.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:00] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4977.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:02] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4978.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:03] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4979.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:04] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4980.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:06] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4981.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:07] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4982.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:08] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4983.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:09] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4984.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:11] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4985.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:12] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4986.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:13] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4987.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:14] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4988.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:16] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4989.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:17] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4990.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:18] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4991.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:19] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4992.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:21] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4993.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:22] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4994.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:23] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4995.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:24] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4996.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:26] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4997.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:27] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4998.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
# 172.17.0.1 - - [03/Apr/2025 21:51:28] "GET /inception/v3/caption/image?url=http%3A%2F%2F172.17.0.1%3A8000%2Fimages%2Fhaunted_image_4999.png&beam_size=5&max_caption_length=20 HTTP/1.1" 200 -
