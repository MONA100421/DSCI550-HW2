# %%
# !git clone https://github.com/USCDataScience/tika-dockers.git
# Out:
# Cloning into 'tika-dockers'...
# remote: Enumerating objects: 71, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 71 (delta 0), reused 0 (delta 0), pack-reused 68 (from 1)
# Receiving objects: 100% (71/71), 22.44 KiB | 433.00 KiB/s, done.
# Resolving deltas: 100% (38/38), done.

# %%
# !docker pull uscdatascience/im2txt-rest-tika
# Out:
# Using default tag: latest
# latest: Pulling from uscdatascience/im2txt-rest-tika
#
# 48dd555d: Pulling fs layer
# 80416e78: Pulling fs layer
# 436b5f80: Pulling fs layer
# 6c3651b3: Pulling fs layer
# 8e74bd34: Pulling fs layer
# 42ce7446: Pulling fs layer
# cf9c7ec5: Pulling fs layer
# b2570269: Pulling fs layer
# 002e7266: Pulling fs layer
# 2abf9103: Pulling fs layer
# 1cf34c3c: Pulling fs layer
# 0ac46c03: Pulling fs layer
# 248d843f: Pulling fs layer
# 957456c0: Pulling fs layer
# 883eca12: Pulling fs layer
# 8ab4a297: Pull complete  189B/189B3kBB16ADigest: sha256:2d51eabc476369335ff83e393a166b1b08e41d4b3cacd34860fc3dd73176eb9c
# Status: Downloaded newer image for uscdatascience/im2txt-rest-tika:latest
# docker.io/uscdatascience/im2txt-rest-tika:latest

# %%
# !docker build -f tika-dockers/Im2txtRestDockerfile -t im2txt-rest-tika .
# Out:
# [+] Building 0.0s (0/0)  docker:default
# [+] Building 0.0s (0/0)  docker:default
# [+] Building 0.0s (0/0)  docker:default
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.1s (0/1)                                          docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.1s
#  => => transferring dockerfile: 40B                                        0.1s
# [+] Building 0.3s (1/2)                                          docker:default
#  => [internal] load build definition from Im2txtRestDockerfile             0.1s
#  => => transferring dockerfile: 2.73kB                                     0.1s
#  => WARN: MaintainerDeprecated: Maintainer instruction is deprecated in f  0.1s
#  => [internal] load metadata for docker.io/uscdatascience/tf-tika-base:la  0.2s
# [+] Building 0.4s (1/3)                                          docker:default
# ...

# %%
# !docker run -it -p 8764:8764 im2txt-rest-tika
# Out:
# INFO:tensorflow:Building model.
# INFO:tensorflow:Initializing vocabulary from file: /usr/share/apache-tika/models/dl/image/caption/1M_iters_ckpt/word_counts.txt
# INFO:tensorflow:Created vocabulary with 11520 words
# 2025-04-04 00:27:19.695801: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# INFO:tensorflow:Loading model from checkpoint: /usr/share/apache-tika/models/dl/image/caption/1M_iters_ckpt/model.ckpt-1000000
# INFO:tensorflow:Restoring parameters from /usr/share/apache-tika/models/dl/image/caption/1M_iters_ckpt/model.ckpt-1000000
# INFO:tensorflow:Successfully loaded checkpoint: model.ckpt-1000000
# Serving on port 8764
#  * Serving Flask app "im2txtapi" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# ...
